# %% [markdown]
# # *Scikit Learn Basic Usage*

# %% [markdown]
# #### *`Import Libraries`*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as skl
import matplotlib as mt

print(f"pd: {pd.__version__}")
print(f"np: {np.__version__}")
print(f"sns: {sns.__version__}")
print(f"mt: {mt.__version__}")
print(f"skl: {skl.__version__}")
# Out:
# pd: 2.3.3
# np: 2.2.6
# sns: 0.13.2
# mt: 3.10.0
# skl: 1.7.2

# %% [markdown]
# ### Load Dataset

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(data=df, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Select Feature and Target

# %%
X = df[["total_bill"]]
y = df["tip"]

# %% [markdown]
# ### Import Linear Regresson Algorithm

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Create the model

# %%
model = LinearRegression()

# %% [markdown]
# ### Train the model

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Make Predictions for unknown bill

# %%
model.predict([[100]])
# Out:
# /home/waseem/miniconda3/envs/ai_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11.42272135])
