# %% [markdown]
# # Feature Design

# %% [markdown]
# ## `Machine Learing in Graphs`
#
# `Goal:` Make Predictions for a set of Objects
#
# `Given:` G= (V,E)
#
# `Learn a funciton:`  f: V -> R
#
# ### `Design Choices:`
# - *Features:* d-dimensional Vectors
# - *Objects:* Nodes, Edges, Sets of Nodes, Entire Graph
# - *Objective Function:* What task are we aiming to solve
#
# `R^dimentions` => Exaample: R^(5x5)
