# %% [markdown]
# # Pandas Dataframes

# %%
import pandas as pd
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# ## Locate Row

# %%
df.loc[0]
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
df.loc[0]       # row 0 → calories=420, duration=50
df.loc[1]       # row 1 → calories=380, duration=40
# Out:
# calories    380
# duration     40
# Name: 1, dtype: int64

# %% [markdown]
# ### Get multiple rows:

# %%
df.loc[0:1]
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %% [markdown]
# ### Get Specific Cell

# %%
df.loc[0, 'calories']
df.loc[1, 'duration']
# Out:
# np.int64(40)

# %% [markdown]
# ### Filter by condition

# %%
df.loc[df['calories'] == 420]
# Out:
#    calories  duration
# 0       420        50

# %%
df.loc[df['calories'] > 385]
# Out:
#    calories  duration
# 0       420        50
# 2       390        45

# %%
df.iloc[0]
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
df.loc[[1, 2, 0]]
# Out:
#    calories  duration
# 1       380        40
# 2       390        45
# 0       420        50

# %% [markdown]
# ### Named Indexes

# %%
data1 = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

newDf = pd.DataFrame(data, index=["Day 1)", "Day 2)", "Day 3)"])
newDf
# Out:
#         calories  duration
# Day 1)       420        50
# Day 2)       380        40
# Day 3)       390        45

# %% [markdown]
# ### Locate Named Indexes

# %%
newDf.loc["Day 2)"]
# Out:
# calories    380
# duration     40
# Name: Day 2), dtype: int64

# %% [markdown]
# ## Load Files Into a DataFrame

# %%
populationDf = pd.read_csv("./Datasets/population.csv")
populationDf
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 0      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 1      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 2      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 3      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 4      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# ..        ...                        ...                        ...
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#             SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0    BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# ...
