# %% [markdown]
# # Viewing the Data

# %%
import pandas as pd
df_population = pd.read_csv('./Datasets/population.csv')
df_recipe = pd.read_json("./Datasets/US_recipes.json")
df_population.head(10)
df_recipe.head(10)
# Out:
#                                                             0     \
# Contient                                           North America
# Country_State                                                 US
# cuisine                                         Southern Recipes
# title                                           Sweet Potato Pie
# URL            https://www.allrecipes.com/recipe/12142/sweet-...
# rating                                                       4.8
# total_time                                                   115
# prep_time                                                     15
# cook_time                                                    100
# description    Shared from a Southern recipe, this homemade s...
#
#                                                             1     \
# Contient                                           North America
# Country_State                                                 US
# cuisine                                         Southern Recipes
# title                               Fresh Southern Peach Cobbler
# URL            https://www.allrecipes.com/recipe/51535/fresh-...
# rating                                                       4.7
# total_time                                                    60
# prep_time                                                     20
# cook_time                                                     40
# description    This peach cobbler recipe makes the perfect de...
#
#                                                             2     \
# Contient                                           North America
# Country_State                                                 US
# cuisine                                         Southern Recipes
# title                                  Best Fried Green Tomatoes
# URL            https://www.allrecipes.com/recipe/16760/best-f...
# rating                                                       4.7
# total_time                                                    20
# prep_time                                                      5
# cook_time                                                     15
# description    Fried green tomatoes are a quick and easy way ...
#
#                                                             3     \
# Contient                                           North America
# Country_State                                                 US
# cuisine                                         Southern Recipes
# title                                             Best Jambalaya
# URL            https://www.allrecipes.com/recipe/31848/jambal...
# rating                                                       4.8
# total_time                                                    65
# prep_time                                                     20
# cook_time                                                     45
# description    A spicy jambalaya with chicken, andouille saus...
#
#                                                             4     \
# Contient                                           North America
# Country_State                                                 US
# cuisine                                         Southern Recipes
# title                     Authentic Louisiana Red Beans and Rice
# URL            https://www.allrecipes.com/recipe/58211/authen...
# rating                                                       4.5
# total_time                                                   690
# prep_time                                                     25
# cook_time                                                    185
# description    This easy authentic Louisiana red beans and ri...
#
#                                                             5     \
# Contient                                           North America
# Country_State                                                 US
# cuisine                                         Southern Recipes
# title                                    Southern Pimento Cheese
# URL            https://www.allrecipes.com/recipe/189930/south...
# rating                                                       4.8
# total_time                                                    15
# prep_time                                                     15
# cook_time                                                   None
# description    Pimento cheese is jazzed up with jalapeño and ...
#
#                                                             6     \
# Contient                                           North America
# Country_State                                                 US
# cuisine                                         Southern Recipes
# title                                     Kickin' Collard Greens
# URL            https://www.allrecipes.com/recipe/51803/kickin...
# rating                                                       4.8
# total_time                                                    70
# prep_time                                                     10
# cook_time                                                     60
# description    These easy Southern collard greens are kickin'...
#
#                                                             7     \
# Contient                                           North America
# Country_State                                                 US
# cuisine                                         Southern Recipes
# title                                             Bananas Foster
# URL            https://www.allrecipes.com/recipe/24705/banana...
# rating                                                       4.8
# total_time                                                    20
# prep_time                                                      5
# cook_time                                                     15
# description    Elegant bananas foster made with bananas cooke...
#
#                                                             8     \
# Contient                                           North America
# Country_State                                                 US
# cuisine                                         Southern Recipes
# title                            Chef John's Buttermilk Biscuits
# URL            https://www.allrecipes.com/recipe/220943/chef-...
# rating                                                       4.7
# total_time                                                    35
# prep_time                                                     20
# cook_time                                                     15
# description    These homemade buttermilk biscuits are buttery...
#
#                                                             9     ...  \
# Contient                                           North America  ...
# Country_State                                                 US  ...
# cuisine                                         Southern Recipes  ...
# title                                     Southern Fried Cabbage  ...
# URL            https://www.allrecipes.com/recipe/73833/southe...  ...
# rating                                                       4.7  ...
# total_time                                                    20  ...
# prep_time                                                     10  ...
# cook_time                                                     10  ...
# description    Fried cabbage with crispy bacon and onion — de...  ...
#
#                                                             8441  \
# Contient                                           North America
# Country_State                                                 US
# cuisine                              Amish and Mennonite Recipes
# title                                       Amish Buttermilk Pie
# URL            https://www.allrecipes.com/recipe/283612/amish...
# rating                                                       4.8
# total_time                                                    80
# prep_time                                                     20
# cook_time                                                     60
# description    Simple, quick, and easy to make, you'll love t...
#
#                                                             8442  \
# Contient                                           North America
# Country_State                                                 US
# cuisine                              Amish and Mennonite Recipes
# title                                      Amish Brown Sugar Pie
# URL            https://www.allrecipes.com/recipe/278338/amish...
# rating                                                      None
# total_time                                                    55
# prep_time                                                     15
# cook_time                                                     40
# description    This brown sugar pie, or "Tears on Your Pillow...
#
#                                                             8443  \
# Contient                                           North America
# Country_State                                                 US
# cuisine                              Amish and Mennonite Recipes
# title                              Red Pepper and Cabbage Pickle
# URL            https://www.allrecipes.com/recipe/256612/red-p...
# rating                                                      None
# total_time                                                   615
# prep_time                                                     45
# cook_time                                                     90
# description    This multi-generational recipe for pickled cab...
#
#                                                             8444  \
# Contient                                           North America
# Country_State                                                 US
# cuisine                              Amish and Mennonite Recipes
# title                                   Moist Herman Coffee Cake
# URL            https://www.allrecipes.com/recipe/7963/moist-h...
# rating                                                       3.7
# total_time                                                     0
# prep_time                                                   None
# cook_time                                                   None
# description    A sourdough spiced coffee cake, also known as ...
#
#                                                             8445  \
# Contient                                           North America
# Country_State                                                 US
# cuisine                              Amish and Mennonite Recipes
# title                                      Amish Buttermilk Cake
# URL            https://www.allrecipes.com/recipe/278340/amish...
# rating                                                      None
# total_time                                                    45
# prep_time                                                     15
# cook_time                                                     30
# description    This traditional Amish recipe for buttermilk c...
#
#                                                             8446  \
# Contient                                           North America
# Country_State                                                 US
# cuisine                              Amish and Mennonite Recipes
# title                                    Amish Chocolate Pudding
# URL            https://www.allrecipes.com/recipe/278333/amish...
# rating                                                       3.3
# total_time                                                    20
# prep_time                                                      5
# cook_time                                                     15
# description    This Amish grandmother's chocolate pudding rec...
#
#                                                             8447  \
# Contient                                           North America
# Country_State                                                 US
# cuisine                              Amish and Mennonite Recipes
# title                                    Gera's Amish Funny Cake
# URL            https://www.allrecipes.com/recipe/139695/geras...
# rating                                                       3.6
# total_time                                                    55
# prep_time                                                     25
# cook_time                                                     30
# description    Amish cooking is amazingly simple and incredib...
#
#                                                             8448  \
# Contient                                           North America
# Country_State                                                 US
# cuisine                              Amish and Mennonite Recipes
# title                                      Quick Banana Nut Cake
# URL            https://www.allrecipes.com/recipe/232881/quick...
# rating                                                       3.0
# total_time                                                    45
# prep_time                                                     15
# cook_time                                                     30
# description    This Amish banana nut cake is a delightful sna...
#
#                                                             8449  \
# Contient                                           North America
# Country_State                                                 US
# cuisine                              Amish and Mennonite Recipes
# title                                 Amish Sour Cream Apple Pie
# URL            https://www.allrecipes.com/recipe/278337/amish...
# rating                                                      None
# total_time                                                    60
# prep_time                                                     15
# cook_time                                                     45
# description    It doesn't get easier or more delicious than t...
#
#                                                             8450
# Contient                                           North America
# Country_State                                                 US
# cuisine                              Amish and Mennonite Recipes
# title          Cherry Amish Friendship Bread Cupcakes with Bu...
# URL            https://www.allrecipes.com/recipe/218218/cherr...
# rating                                                       4.0
# total_time                                                    70
# prep_time                                                     20
# cook_time                                                     20
# description    Pink cherry cupcakes topped with fluffy butter...
#
# [10 rows x 8451 columns]

# %% [markdown]
# # Data Info

# %%
df_recipe.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 14 entries, Contient to serves
# Columns: 8451 entries, 0 to 8450
# dtypes: object(8451)
# memory usage: 924.4+ KB

# %%
df_recipe.describe()
# Out:
#                  0              1              2              3     \
# count              14             14             14             14
# unique             14             14             14             14
# top     North America  North America  North America  North America
# freq                1              1              1              1
#
#                  4     5              6              7              8     \
# count              14    13             14             14             14
# unique             14    12             14             14             14
# top     North America    15  North America  North America  North America
# freq                1     2              1              1              1
#
#         9     ...           8441           8442           8443           8444  \
# count     14  ...             14             13             13             12
# unique    13  ...             14             13             13             12
# top       10  ...  North America  North America  North America  North America
# freq       2  ...              1              1              1              1
#
#                  8445           8446           8447           8448  \
# count              13             14             14             14
# unique             13             14             14             14
# top     North America  North America  North America  North America
# freq                1              1              1              1
#
#                  8449  8450
# count              13    14
# unique             13    13
# top     North America    20
# freq                1     2
#
# [4 rows x 8451 columns]
