# %% [markdown]
# # Countries Project

# %% [markdown]
# #### import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### import Countries Data

# %%
df = pd.read_csv("./Countries.csv")

# %% [markdown]
# #### Data-Preprocessing

# %%
df.shape
# Out:
# (194, 64)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    str
#  1   country_long                             194 non-null    str
#  2   currency                                 194 non-null    str
#  3   capital_city                             194 non-null    str
#  4   region                                   194 non-null    str
#  5   continent                                194 non-null    str
#  6   demonym                                  194 non-null    str
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
df.describe()
# Out:
#          latitude   longitude  agricultural_land   forest_area     land_area  \
# count  194.000000  194.000000       1.930000e+02  1.940000e+02  1.940000e+02
# mean    18.975601   22.027491       2.454551e+05  2.086784e+05  6.675087e+05
# std     23.876225   66.396389       6.356268e+05  7.824926e+05  1.837107e+06
# min    -41.000000 -175.000000       4.000000e+00  0.000000e+00  2.027000e+00
# 25%      4.000000   -5.000000       6.464000e+03  3.331775e+03  2.355250e+04
# 50%     16.583333   21.500000       3.872780e+04  2.528925e+04  1.203750e+05
# 75%     40.000000   50.162500       2.150000e+05  1.236735e+05  5.237000e+05
# max     65.000000  178.000000       5.285080e+06  8.153120e+06  1.637690e+07
#
#          rural_land     urban_land  central_government_debt_pct_gdp  \
# count  1.940000e+02     194.000000                       120.000000
# mean   6.563711e+05    9777.116531                        66.759366
# std    1.811169e+06   42301.458421                        71.806247
# ...

# %%
df.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        3.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
# ...

# %%
df.tail()
# Out:
#                 country                   country_long            currency  \
# 189             Vietnam  Socialist Republic of Vietnam     Vietnamese dong
# 190  West Bank and Gaza             West Bank and Gaza  Israeli new shekel
# 191               Yemen              Republic of Yemen         Yemeni rial
# 192              Zambia             Republic of Zambia  New Zambian kwacha
# 193            Zimbabwe           Republic of Zimbabwe         U.S. dollar
#
#     capital_city              region continent      demonym   latitude  \
# 189        Hanoi  South-Eastern Asia      Asia   Vietnamese  16.166667
# 190     Ramallah        Western Asia      Asia  Palestinian  31.900000
# 191       Sana'a        Western Asia      Asia       Yemeni  15.000000
# 192       Lusaka      Eastern Africa    Africa      Zambian -15.000000
# 193       Harare      Eastern Africa    Africa   Zimbabwean -20.000000
#
#       longitude  agricultural_land  ...  population  \
# ...

# %%
df[df["population"] == df["population"].max()][["country", "capital_city", "population"]]
# Out:
#    country capital_city  population
# 75   India    New Delhi  1417173173

# %%
df[df["population"] == df["population"].min()][["country", "capital_city" , "population"]]
# Out:
#     country capital_city  population
# 179  Tuvalu     Funafuti       11312

# %%
df.nlargest(5, "democracy_score")[["country"]].sort_values(by="country")
# Out:
#          country
# 46       Denmark
# 74       Iceland
# 122  New Zealand
# 127       Norway
# 164       Sweden

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'currency', 'capital_city', 'region',
#        'continent', 'demonym', 'latitude', 'longitude', 'agricultural_land',
#        'forest_area', 'land_area', 'rural_land', 'urban_land',
#        'central_government_debt_pct_gdp', 'expense_pct_gdp', 'gdp',
#        'inflation', 'self_employed_pct', 'tax_revenue_pct_gdp',
#        'unemployment_pct', 'vulnerable_employment_pct',
#        'electricity_access_pct', 'alternative_nuclear_energy_pct',
#        'electricty_production_coal_pct',
#        'electricty_production_hydroelectric_pct',
#        'electricty_production_gas_pct', 'electricty_production_nuclear_pct',
#        'electricty_production_oil_pct', 'electricty_production_renewable_pct',
#        'energy_imports_pct', 'fossil_energy_consumption_pct',
#        'renewable_energy_consumption_pct', 'co2_emissions',
#        'methane_emissions', 'nitrous_oxide_emissions',
#        'greenhouse_other_emissions', 'urban_population_under_5m',
# ...

# %%
"region" in df.columns
# Out:
# True

# %%
[col for col in df.columns if "region" in col.lower()]
# Out:
# ['region']

# %%
df["region"].nunique()
# Out:
# 22

# %%
grp = df.groupby("region").sum()
grp
# Out:
#                                                                      country  \
# region
# Australia and New Zealand                               AustraliaNew Zealand
# Caribbean                  Antigua and BarbudaBarbadosCubaDominicaDominic...
# Central America            BelizeCosta RicaEl SalvadorGuatemalaHondurasMe...
# Central Asia               KazakhstanKyrgyz RepublicTajikistanTurkmenista...
# Eastern Africa             BurundiComorosDjiboutiEritreaEthiopiaKenyaMada...
# Eastern Asia                 ChinaDem. People's Rep. KoreaJapanKoreaMongolia
# Eastern Europe             BelarusBulgariaCzech RepublicHungaryMoldovaPol...
# Melanesia                         FijiPapua New GuineaSolomon IslandsVanuatu
# Micronesia                      KiribatiMarshall IslandsMicronesiaNauruPalau
# Middle Africa              AngolaCameroonCentral African RepublicChadCong...
# Northern Africa                         AlgeriaEgyptLibyaMoroccoSudanTunisia
# ...

# %%
df["region"].unique()
# Out:
# <StringArray>
# [            'Southern Asia',           'Southern Europe',
#            'Northern Africa',             'Middle Africa',
#                  'Caribbean',             'South America',
#               'Western Asia', 'Australia and New Zealand',
#             'Western Europe',            'Eastern Europe',
#            'Central America',            'Western Africa',
#            'Southern Africa',        'South-Eastern Asia',
#             'Eastern Africa',          'Northern America',
#               'Eastern Asia',           'Northern Europe',
#                  'Melanesia',              'Central Asia',
#                 'Micronesia',                 'Polynesia']
# Length: 22, dtype: str

# %%
df["region"].value_counts()
# Out:
# region
# Western Asia                 17
# Eastern Africa               17
# Western Africa               16
# Southern Europe              15
# Caribbean                    13
# South America                12
# South-Eastern Asia           11
# Middle Africa                10
# Eastern Europe               10
# Northern Europe              10
# Southern Asia                 9
# Western Europe                9
# Central America               8
# Northern Africa               6
# Southern Africa               5
# Eastern Asia                  5
# Central Asia                  5
# Micronesia                    5
# Melanesia                     4
# Polynesia                     3
# Australia and New Zealand     2
# Northern America              2
# Name: count, dtype: int64

# %%
df["region"].value_counts()
# Out:
# region
# Western Asia                 17
# Eastern Africa               17
# Western Africa               16
# Southern Europe              15
# Caribbean                    13
# South America                12
# South-Eastern Asia           11
# Middle Africa                10
# Eastern Europe               10
# Northern Europe              10
# Southern Asia                 9
# Western Europe                9
# Central America               8
# Northern Africa               6
# Southern Africa               5
# Eastern Asia                  5
# Central Asia                  5
# Micronesia                    5
# Melanesia                     4
# Polynesia                     3
# Australia and New Zealand     2
# Northern America              2
# Name: count, dtype: int64

# %%
df["region"].value_counts().idxmax()
# Out:
# 'Western Asia'

# %%
df["region"].value_counts().max()
# Out:
# np.int64(17)

# %%
region = df["region"].value_counts().idxmax()
count = df["region"].value_counts().max()

region, count
# Out:
# ('Western Asia', np.int64(17))

# %%
df[df["region"] == "Eastern Europe"]["country"]
# Out:
# 14             Belarus
# 24            Bulgaria
# 43      Czech Republic
# 73             Hungary
# 111            Moldova
# 136             Poland
# 139            Romania
# 140             Russia
# 151    Slovak Republic
# 181            Ukraine
# Name: country, dtype: str

# %%
len(df[df["region"] == "Eastern Europe"])
# Out:
# 10

# %%
df[df["region"] == "Eastern Europe"].shape[0]
# Out:
# 10

# %%
df["region"].value_counts()["Eastern Europe"]
# Out:
# np.int64(10)

# %%
df[df["population"] == df["population"].nlargest(2).iloc[1]]["political_leader"]
# Out:
# 34    Xi Jinping
# Name: political_leader, dtype: str

# %%
df[df["country"] == "Pakistan"]["political_leader"]
# Out:
# 129    Imran Khan
# Name: political_leader, dtype: str

# %%
df.loc[df["political_leader"].isna()]["country"]
# Out:
# 27                         Cabo Verde
# 151                   Slovak Republic
# 159               St. Kitts and Nevis
# 160                         St. Lucia
# 161    St. Vincent and the Grenadines
# 172                       Timor-Leste
# 190                West Bank and Gaza
# Name: country, dtype: str

# %%
df.loc[df["political_leader"].isna()]["country"].count()
# Out:
# np.int64(7)

# %%
df[df["country_long"].str.contains("Republic")]["country"]
# Out:
# 1        Albania
# 2        Algeria
# 4         Angola
# 6      Argentina
# 7        Armenia
#          ...
# 187      Vanuatu
# 189      Vietnam
# 191        Yemen
# 192       Zambia
# 193     Zimbabwe
# Name: country, Length: 125, dtype: str

# %%
count = 0
def counting(txt):
    global count
    if "republic" in txt.lower():
        count+=1
    return txt

# %%
df["country_long"] = df["country_long"].apply(counting)
print(count)
# Out:
# 125

# %%
df[df["continent"] == "Africa"].nlargest(1, "population")[["country", "country_long", "population"]]
# Out:
#      country                 country_long  population
# 125  Nigeria  Federal Republic of Nigeria   218541212
