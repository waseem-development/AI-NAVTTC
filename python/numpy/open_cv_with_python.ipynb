# %% [markdown]
# # Work with images

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread("./images/japan_street.jpg", 1)

# cv2.imshow("Japan Street", img)

# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (3264, 4928)

# %%
crop = img[1200:2500, 1000:2001] # first argument is for rows. second for cols
cv2.imshow("Cropped Japan Street", crop)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# QFontDatabase: Cannot find font directory /home/waseem/miniconda3/envs/numpy_env/lib/python3.13/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/waseem/miniconda3/envs/numpy_env/lib/python3.13/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/waseem/miniconda3/envs/numpy_env/lib/python3.13/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/waseem/miniconda3/envs/numpy_env/lib/python3.13/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/waseem/miniconda3/envs/numpy_env/lib/python3.13/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
