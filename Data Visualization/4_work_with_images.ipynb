# %% [markdown]
# # Learn to Work with Images in Matplotlib

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
img = mpimg.imread('./flower.jpg')
img
# Out:
# array([[[15, 40, 18],
#         [15, 40, 18],
#         [16, 41, 19],
#         ...,
#         [51, 82, 48],
#         [51, 82, 48],
#         [51, 82, 48]],
#
#        [[16, 40, 18],
#         [15, 40, 18],
#         [15, 40, 18],
#         ...,
#         [50, 81, 47],
#         [51, 82, 48],
#         [51, 82, 48]],
#
#        [[16, 40, 18],
#         [16, 40, 18],
#         [15, 40, 18],
#         ...,
#         [49, 80, 46],
#         [50, 81, 47],
#         [50, 81, 47]],
#
#        ...,
#
#        [[ 8, 26, 14],
#         [ 9, 27, 15],
#         [10, 28, 16],
#         ...,
#         [29, 42, 32],
#         [31, 44, 34],
#         [32, 45, 35]],
#
#        [[ 8, 26, 14],
#         [ 9, 27, 15],
#         [10, 28, 16],
#         ...,
#         [32, 45, 35],
#         [34, 47, 37],
#         [35, 48, 38]],
#
#        [[ 8, 26, 14],
#         [ 9, 27, 15],
#         [10, 28, 16],
#         ...,
#         [33, 46, 36],
#         [35, 48, 38],
# ...

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(11007.5), np.float64(6143.5), np.float64(-0.5))

# %%
cropped_img = img[50:200, 100:300]
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(149.5), np.float64(-0.5))
