# %% [markdown]
# # Objec Oriented Way of Data Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(1, 10, 10)
y = x**2
z = x**3
a = y**2
b = a**2
c = b**2

# %%
plt.plot(x,y)

# %%
fig = plt.figure(figsize=(20,8), dpi=1000) # 20 with and 8 height
axis1 = fig.add_axes([0.1, 0.1, 0.8,0.8]) # from left 0.1 (means 10%), from bottom 0.1 (means 10%), 80% width and 80% height
axis1.plot(x,y)
axis2 = fig.add_axes([0.3, 0.6, 0.3,0.3])
axis2.plot(x,y)
