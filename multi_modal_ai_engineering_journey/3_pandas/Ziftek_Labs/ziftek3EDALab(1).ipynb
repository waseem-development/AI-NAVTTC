# %%
import pandas as pd
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt 
import requests
import seaborn as sns

# %%
path =r"./datasets/gasoline_data.csv"
data = pd.read_csv(path)

# %%
data.head()
# Out:
#   REF_DATE                                                GEO         DGUID  \
# 0   Jan-79              St. John's, Newfoundland and Labrador  2011S0503001
# 1   Jan-79  Charlottetown and Summerside, Prince Edward Is...           NaN
# 2   Jan-79                               Halifax, Nova Scotia  2011S0503205
# 3   Jan-79                          Saint John, New Brunswick  2011S0503310
# 4   Jan-79                                     Québec, Quebec  2011S0503421
#
#                                         Type of fuel              UOM  UOM_ID  \
# 0  Regular unleaded gasoline at full service fill...  Cents per litre      57
# 1  Regular unleaded gasoline at full service fill...  Cents per litre      57
# 2  Regular unleaded gasoline at full service fill...  Cents per litre      57
# 3  Regular unleaded gasoline at full service fill...  Cents per litre      57
# 4  Regular unleaded gasoline at full service fill...  Cents per litre      57
#
#   SCALAR_FACTOR  SCALAR_ID   VECTOR  COORDINATE  VALUE  STATUS  SYMBOL  \
# 0        units           0  v735046         2.1   26.0     NaN     NaN
# 1        units           0  v735056         3.1   24.6     NaN     NaN
# 2        units           0  v735057         4.1   23.4     NaN     NaN
# 3        units           0  v735058         5.1   23.2     NaN     NaN
# 4        units           0  v735059         6.1   22.6     NaN     NaN
#
#   TERMINATED  DECIMALS
# 0          t         1
# 1          t         1
# 2          t         1
# 3          t         1
# 4          t         1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41942 entries, 0 to 41941
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   REF_DATE       41942 non-null  object
#  1   GEO            41942 non-null  object
#  2   DGUID          39451 non-null  object
#  3   Type of fuel   41942 non-null  object
#  4   UOM            41942 non-null  object
#  5   UOM_ID         41942 non-null  int64
#  6   SCALAR_FACTOR  41942 non-null  object
#  7   SCALAR_ID      41942 non-null  int64
#  8   VECTOR         41942 non-null  object
#  9   COORDINATE     41942 non-null  float64
#  10  VALUE          41942 non-null  float64
#  11  STATUS         0 non-null      float64
#  12  SYMBOL         0 non-null      float64
#  13  TERMINATED     16564 non-null  object
#  14  DECIMALS       41942 non-null  int64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 4.8+ MB

# %%
data.shape
# Out:
# (41942, 15)

# %%
data.columns.tolist()
# Out:
# ['REF_DATE',
#  'GEO',
#  'DGUID',
#  'Type of fuel',
#  'UOM',
#  'UOM_ID',
#  'SCALAR_FACTOR',
#  'SCALAR_ID',
#  'VECTOR',
#  'COORDINATE',
#  'VALUE',
#  'STATUS',
#  'SYMBOL',
#  'TERMINATED',
#  'DECIMALS']

# %%
data.isnull().sum()
# Out:
# REF_DATE             0
# GEO                  0
# DGUID             2491
# Type of fuel         0
# UOM                  0
# UOM_ID               0
# SCALAR_FACTOR        0
# SCALAR_ID            0
# VECTOR               0
# COORDINATE           0
# VALUE                0
# STATUS           41942
# SYMBOL           41942
# TERMINATED       25378
# DECIMALS             0
# dtype: int64

# %%
dat_copy = (data[['REF_DATE','GEO','Type of fuel','VALUE']]).rename(columns={"REF_DATE" : "DATE", "Type of fuel" : "TYPE"})
dat_copy.head()
# Out:
#      DATE                                                GEO  \
# 0  Jan-79              St. John's, Newfoundland and Labrador
# 1  Jan-79  Charlottetown and Summerside, Prince Edward Is...
# 2  Jan-79                               Halifax, Nova Scotia
# 3  Jan-79                          Saint John, New Brunswick
# 4  Jan-79                                     Québec, Quebec
#
#                                                 TYPE  VALUE
# 0  Regular unleaded gasoline at full service fill...   26.0
# 1  Regular unleaded gasoline at full service fill...   24.6
# 2  Regular unleaded gasoline at full service fill...   23.4
# 3  Regular unleaded gasoline at full service fill...   23.2
# 4  Regular unleaded gasoline at full service fill...   22.6

# %%
dat_copy[['City', 'Province']] = data['GEO'].str.split(',', n=1, expand=True)

# %%
dat_copy.head()
# Out:
#      DATE                                                GEO  \
# 0  Jan-79              St. John's, Newfoundland and Labrador
# 1  Jan-79  Charlottetown and Summerside, Prince Edward Is...
# 2  Jan-79                               Halifax, Nova Scotia
# 3  Jan-79                          Saint John, New Brunswick
# 4  Jan-79                                     Québec, Quebec
#
#                                                 TYPE  VALUE  \
# 0  Regular unleaded gasoline at full service fill...   26.0
# 1  Regular unleaded gasoline at full service fill...   24.6
# 2  Regular unleaded gasoline at full service fill...   23.4
# 3  Regular unleaded gasoline at full service fill...   23.2
# 4  Regular unleaded gasoline at full service fill...   22.6
#
#                            City                    Province
# 0                    St. John's   Newfoundland and Labrador
# 1  Charlottetown and Summerside        Prince Edward Island
# 2                       Halifax                 Nova Scotia
# 3                    Saint John               New Brunswick
# 4                        Québec                      Quebec

# %%
dat_copy['DATE'] = pd.to_datetime(dat_copy['DATE'], format='%b-%y')
dat_copy['Month'] = dat_copy['DATE'].dt.month_name().str.slice(stop=3)

# %%
dat_copy.head().T
# Out:
#                                                           0  \
# DATE                                    1979-01-01 00:00:00
# GEO                   St. John's, Newfoundland and Labrador
# TYPE      Regular unleaded gasoline at full service fill...
# VALUE                                                  26.0
# City                                             St. John's
# Province                          Newfoundland and Labrador
# Month                                                   Jan
#
#                                                           1  \
# DATE                                    1979-01-01 00:00:00
# GEO       Charlottetown and Summerside, Prince Edward Is...
# TYPE      Regular unleaded gasoline at full service fill...
# VALUE                                                  24.6
# City                           Charlottetown and Summerside
# Province                               Prince Edward Island
# Month                                                   Jan
#
#                                                           2  \
# DATE                                    1979-01-01 00:00:00
# GEO                                    Halifax, Nova Scotia
# TYPE      Regular unleaded gasoline at full service fill...
# VALUE                                                  23.4
# City                                                Halifax
# Province                                        Nova Scotia
# Month                                                   Jan
#
#                                                           3  \
# DATE                                    1979-01-01 00:00:00
# GEO                               Saint John, New Brunswick
# TYPE      Regular unleaded gasoline at full service fill...
# VALUE                                                  23.2
# City                                             Saint John
# Province                                      New Brunswick
# Month                                                   Jan
#
#                                                           4
# DATE                                    1979-01-01 00:00:00
# GEO                                          Québec, Quebec
# TYPE      Regular unleaded gasoline at full service fill...
# VALUE                                                  22.6
# City                                                 Québec
# Province                                             Quebec
# Month                                                   Jan

# %%
dat_copy['Year'] = dat_copy['DATE'].dt.year

# %%
dat_copy.head().T
# Out:
#                                                           0  \
# DATE                                    1979-01-01 00:00:00
# GEO                   St. John's, Newfoundland and Labrador
# TYPE      Regular unleaded gasoline at full service fill...
# VALUE                                                  26.0
# City                                             St. John's
# Province                          Newfoundland and Labrador
# Month                                                   Jan
# Year                                                   1979
#
#                                                           1  \
# DATE                                    1979-01-01 00:00:00
# GEO       Charlottetown and Summerside, Prince Edward Is...
# TYPE      Regular unleaded gasoline at full service fill...
# VALUE                                                  24.6
# City                           Charlottetown and Summerside
# Province                               Prince Edward Island
# Month                                                   Jan
# Year                                                   1979
#
#                                                           2  \
# DATE                                    1979-01-01 00:00:00
# GEO                                    Halifax, Nova Scotia
# TYPE      Regular unleaded gasoline at full service fill...
# VALUE                                                  23.4
# City                                                Halifax
# Province                                        Nova Scotia
# Month                                                   Jan
# Year                                                   1979
#
#                                                           3  \
# DATE                                    1979-01-01 00:00:00
# GEO                               Saint John, New Brunswick
# TYPE      Regular unleaded gasoline at full service fill...
# VALUE                                                  23.2
# City                                             Saint John
# Province                                      New Brunswick
# Month                                                   Jan
# Year                                                   1979
#
#                                                           4
# DATE                                    1979-01-01 00:00:00
# GEO                                          Québec, Quebec
# TYPE      Regular unleaded gasoline at full service fill...
# VALUE                                                  22.6
# City                                                 Québec
# Province                                             Quebec
# Month                                                   Jan
# Year                                                   1979

# %%
dat_copy.VALUE.describe()
# Out:
# count    41942.000000
# mean        84.784858
# std         31.492697
# min         18.300000
# 25%         58.200000
# 50%         79.200000
# 75%        110.900000
# max        191.600000
# Name: VALUE, dtype: float64

# %%
dat_copy.VALUE.hist()
# Out:
# <Axes: >

# %%
sns.distplot(dat_copy["VALUE"],kde=True)
# Out:
# /tmp/ipykernel_12365/642549358.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dat_copy["VALUE"],kde=True)
# <Axes: xlabel='VALUE', ylabel='Density'>

# %%
dat_copy.GEO.unique()
# Out:
# array(["St. John's, Newfoundland and Labrador",
#        'Charlottetown and Summerside, Prince Edward Island',
#        'Halifax, Nova Scotia', 'Saint John, New Brunswick',
#        'Québec, Quebec', 'Montréal, Quebec',
#        'Ottawa-Gatineau, Ontario part, Ontario/Quebec',
#        'Toronto, Ontario', 'Thunder Bay, Ontario', 'Winnipeg, Manitoba',
#        'Regina, Saskatchewan', 'Saskatoon, Saskatchewan',
#        'Edmonton, Alberta', 'Calgary, Alberta',
#        'Vancouver, British Columbia', 'Victoria, British Columbia',
#        'Whitehorse, Yukon', 'Yellowknife, Northwest Territories'],
#       dtype=object)

# %%
dat_copy.GEO.nunique()
# Out:
# 18

# %%
dat_copy.GEO.value_counts()
# Out:
# GEO
# Charlottetown and Summerside, Prince Edward Island    2491
# Montréal, Quebec                                      2491
# Winnipeg, Manitoba                                    2491
# Québec, Quebec                                        2491
# Toronto, Ontario                                      2491
# Ottawa-Gatineau, Ontario part, Ontario/Quebec         2491
# Vancouver, British Columbia                           2491
# Regina, Saskatchewan                                  2491
# Victoria, British Columbia                            2467
# Whitehorse, Yukon                                     2359
# Yellowknife, Northwest Territories                    2339
# Saskatoon, Saskatchewan                               2274
# St. John's, Newfoundland and Labrador                 2215
# Halifax, Nova Scotia                                  2163
# Saint John, New Brunswick                             2147
# Calgary, Alberta                                      2109
# Edmonton, Alberta                                     2109
# Thunder Bay, Ontario                                  1832
# Name: count, dtype: int64

# %%
dat_copy.TYPE.unique().tolist()
# Out:
# ['Regular unleaded gasoline at full service filling stations',
#  'Regular unleaded gasoline at self service filling stations',
#  'Premium unleaded gasoline at full service filling stations',
#  'Premium unleaded gasoline at self service filling stations',
#  'Diesel fuel at full service filling stations',
#  'Household heating fuel',
#  'Diesel fuel at self service filling stations']

# %%
dat_copy.TYPE.nunique()
# Out:
# 7

# %%
dat_copy.TYPE.value_counts()
# Out:
# TYPE
# Regular unleaded gasoline at full service filling stations    7086
# Regular unleaded gasoline at self service filling stations    6816
# Premium unleaded gasoline at self service filling stations    6796
# Household heating fuel                                        6112
# Diesel fuel at self service filling stations                  5654
# Premium unleaded gasoline at full service filling stations    4986
# Diesel fuel at full service filling stations                  4492
# Name: count, dtype: int64

# %%
calgary = dat_copy[dat_copy['GEO'] == 'Calgary, Alberta']
calgary
# Out:
#             DATE               GEO  \
# 13    1979-01-01  Calgary, Alberta
# 28    1979-02-01  Calgary, Alberta
# 43    1979-03-01  Calgary, Alberta
# 58    1979-04-01  Calgary, Alberta
# 73    1979-05-01  Calgary, Alberta
# ...          ...               ...
# 41855 2021-09-01  Calgary, Alberta
# 41856 2021-09-01  Calgary, Alberta
# 41923 2021-10-01  Calgary, Alberta
# 41924 2021-10-01  Calgary, Alberta
# 41925 2021-10-01  Calgary, Alberta
#
#                                                     TYPE  VALUE     City  \
# 13     Regular unleaded gasoline at full service fill...   18.7  Calgary
# 28     Regular unleaded gasoline at full service fill...   18.9  Calgary
# 43     Regular unleaded gasoline at full service fill...   18.9  Calgary
# 58     Regular unleaded gasoline at full service fill...   19.1  Calgary
# 73     Regular unleaded gasoline at full service fill...   19.2  Calgary
# ...                                                  ...    ...      ...
# 41855  Premium unleaded gasoline at self service fill...  156.6  Calgary
# 41856       Diesel fuel at self service filling stations  125.1  Calgary
# 41923  Regular unleaded gasoline at self service fill...  140.8  Calgary
# 41924  Premium unleaded gasoline at self service fill...  164.4  Calgary
# 41925       Diesel fuel at self service filling stations  138.3  Calgary
#
#        Province Month  Year
# 13      Alberta   Jan  1979
# 28      Alberta   Feb  1979
# 43      Alberta   Mar  1979
# 58      Alberta   Apr  1979
# 73      Alberta   May  1979
# ...         ...   ...   ...
# 41855   Alberta   Sep  2021
# 41856   Alberta   Sep  2021
# 41923   Alberta   Oct  2021
# 41924   Alberta   Oct  2021
# 41925   Alberta   Oct  2021
#
# [2109 rows x 8 columns]

# %%
ad_alber = dat_copy[dat_copy["GEO"]=="Edmonton, Alberta"]
ad_alber
# Out:
#             DATE                GEO  \
# 12    1979-01-01  Edmonton, Alberta
# 27    1979-02-01  Edmonton, Alberta
# 42    1979-03-01  Edmonton, Alberta
# 57    1979-04-01  Edmonton, Alberta
# 72    1979-05-01  Edmonton, Alberta
# ...          ...                ...
# 41852 2021-09-01  Edmonton, Alberta
# 41853 2021-09-01  Edmonton, Alberta
# 41920 2021-10-01  Edmonton, Alberta
# 41921 2021-10-01  Edmonton, Alberta
# 41922 2021-10-01  Edmonton, Alberta
#
#                                                     TYPE  VALUE      City  \
# 12     Regular unleaded gasoline at full service fill...   18.3  Edmonton
# 27     Regular unleaded gasoline at full service fill...   18.5  Edmonton
# 42     Regular unleaded gasoline at full service fill...   18.4  Edmonton
# 57     Regular unleaded gasoline at full service fill...   18.4  Edmonton
# 72     Regular unleaded gasoline at full service fill...   18.6  Edmonton
# ...                                                  ...    ...       ...
# 41852  Premium unleaded gasoline at self service fill...  150.7  Edmonton
# 41853       Diesel fuel at self service filling stations  123.9  Edmonton
# 41920  Regular unleaded gasoline at self service fill...  138.3  Edmonton
# 41921  Premium unleaded gasoline at self service fill...  159.6  Edmonton
# 41922       Diesel fuel at self service filling stations  134.7  Edmonton
#
#        Province Month  Year
# 12      Alberta   Jan  1979
# 27      Alberta   Feb  1979
# 42      Alberta   Mar  1979
# 57      Alberta   Apr  1979
# 72      Alberta   May  1979
# ...         ...   ...   ...
# 41852   Alberta   Sep  2021
# 41853   Alberta   Sep  2021
# 41920   Alberta   Oct  2021
# 41921   Alberta   Oct  2021
# 41922   Alberta   Oct  2021
#
# [2109 rows x 8 columns]

# %%
tornto_orinto = dat_copy[dat_copy["GEO"]== 'Toronto, Ontario']
tornto_orinto
# Out:
#             DATE               GEO  \
# 7     1979-01-01  Toronto, Ontario
# 22    1979-02-01  Toronto, Ontario
# 37    1979-03-01  Toronto, Ontario
# 52    1979-04-01  Toronto, Ontario
# 67    1979-05-01  Toronto, Ontario
# ...          ...               ...
# 41835 2021-09-01  Toronto, Ontario
# 41901 2021-10-01  Toronto, Ontario
# 41902 2021-10-01  Toronto, Ontario
# 41903 2021-10-01  Toronto, Ontario
# 41904 2021-10-01  Toronto, Ontario
#
#                                                     TYPE  VALUE     City  \
# 7      Regular unleaded gasoline at full service fill...   23.0  Toronto
# 22     Regular unleaded gasoline at full service fill...   23.2  Toronto
# 37     Regular unleaded gasoline at full service fill...   23.2  Toronto
# 52     Regular unleaded gasoline at full service fill...   23.4  Toronto
# 67     Regular unleaded gasoline at full service fill...   23.4  Toronto
# ...                                                  ...    ...      ...
# 41835                             Household heating fuel  144.4  Toronto
# 41901  Regular unleaded gasoline at self service fill...  145.3  Toronto
# 41902  Premium unleaded gasoline at self service fill...  170.7  Toronto
# 41903       Diesel fuel at self service filling stations  141.3  Toronto
# 41904                             Household heating fuel  148.0  Toronto
#
#        Province Month  Year
# 7       Ontario   Jan  1979
# 22      Ontario   Feb  1979
# 37      Ontario   Mar  1979
# 52      Ontario   Apr  1979
# 67      Ontario   May  1979
# ...         ...   ...   ...
# 41835   Ontario   Sep  2021
# 41901   Ontario   Oct  2021
# 41902   Ontario   Oct  2021
# 41903   Ontario   Oct  2021
# 41904   Ontario   Oct  2021
#
# [2491 rows x 8 columns]

# %%
mult_loc = dat_copy[(dat_copy['Year'] > 2000) & (dat_copy['Year'] < 2010)]
mult_loc
# Out:
#             DATE                                    GEO  \
# 17584 2001-01-01  St. John's, Newfoundland and Labrador
# 17585 2001-01-01  St. John's, Newfoundland and Labrador
# 17586 2001-01-01  St. John's, Newfoundland and Labrador
# 17587 2001-01-01  St. John's, Newfoundland and Labrador
# 17588 2001-01-01  St. John's, Newfoundland and Labrador
# ...          ...                                    ...
# 30323 2009-12-01     Yellowknife, Northwest Territories
# 30324 2009-12-01     Yellowknife, Northwest Territories
# 30325 2009-12-01     Yellowknife, Northwest Territories
# 30326 2009-12-01     Yellowknife, Northwest Territories
# 30327 2009-12-01     Yellowknife, Northwest Territories
#
#                                                     TYPE  VALUE         City  \
# 17584  Regular unleaded gasoline at full service fill...   83.6   St. John's
# 17585  Regular unleaded gasoline at self service fill...   81.1   St. John's
# 17586  Premium unleaded gasoline at full service fill...   90.3   St. John's
# 17587  Premium unleaded gasoline at self service fill...   87.7   St. John's
# 17588       Diesel fuel at full service filling stations   91.4   St. John's
# ...                                                  ...    ...          ...
# 30323  Premium unleaded gasoline at full service fill...  130.9  Yellowknife
# 30324  Premium unleaded gasoline at self service fill...  128.7  Yellowknife
# 30325       Diesel fuel at full service filling stations  105.9  Yellowknife
# 30326       Diesel fuel at self service filling stations  102.2  Yellowknife
# 30327                             Household heating fuel   94.2  Yellowknife
#
#                          Province Month  Year
# 17584   Newfoundland and Labrador   Jan  2001
# 17585   Newfoundland and Labrador   Jan  2001
# 17586   Newfoundland and Labrador   Jan  2001
# 17587   Newfoundland and Labrador   Jan  2001
# 17588   Newfoundland and Labrador   Jan  2001
# ...                           ...   ...   ...
# 30323       Northwest Territories   Dec  2009
# 30324       Northwest Territories   Dec  2009
# 30325       Northwest Territories   Dec  2009
# 30326       Northwest Territories   Dec  2009
# 30327       Northwest Territories   Dec  2009
#
# [12744 rows x 8 columns]

# %%
geo_filter = dat_copy[(dat_copy["GEO"]=="Toronto, Ontario") | (dat_copy["GEO"]=="Edmonton, Alberta")]
geo_filter
# Out:
#             DATE                GEO  \
# 7     1979-01-01   Toronto, Ontario
# 12    1979-01-01  Edmonton, Alberta
# 22    1979-02-01   Toronto, Ontario
# 27    1979-02-01  Edmonton, Alberta
# 37    1979-03-01   Toronto, Ontario
# ...          ...                ...
# 41903 2021-10-01   Toronto, Ontario
# 41904 2021-10-01   Toronto, Ontario
# 41920 2021-10-01  Edmonton, Alberta
# 41921 2021-10-01  Edmonton, Alberta
# 41922 2021-10-01  Edmonton, Alberta
#
#                                                     TYPE  VALUE      City  \
# 7      Regular unleaded gasoline at full service fill...   23.0   Toronto
# 12     Regular unleaded gasoline at full service fill...   18.3  Edmonton
# 22     Regular unleaded gasoline at full service fill...   23.2   Toronto
# 27     Regular unleaded gasoline at full service fill...   18.5  Edmonton
# 37     Regular unleaded gasoline at full service fill...   23.2   Toronto
# ...                                                  ...    ...       ...
# 41903       Diesel fuel at self service filling stations  141.3   Toronto
# 41904                             Household heating fuel  148.0   Toronto
# 41920  Regular unleaded gasoline at self service fill...  138.3  Edmonton
# 41921  Premium unleaded gasoline at self service fill...  159.6  Edmonton
# 41922       Diesel fuel at self service filling stations  134.7  Edmonton
#
#        Province Month  Year
# 7       Ontario   Jan  1979
# 12      Alberta   Jan  1979
# 22      Ontario   Feb  1979
# 27      Alberta   Feb  1979
# 37      Ontario   Mar  1979
# ...         ...   ...   ...
# 41903   Ontario   Oct  2021
# 41904   Ontario   Oct  2021
# 41920   Alberta   Oct  2021
# 41921   Alberta   Oct  2021
# 41922   Alberta   Oct  2021
#
# [4600 rows x 8 columns]

# %%
cities = ['Calgary', 'alberta', 'Edmonton',"Vancouver"]
new_city = dat_copy[dat_copy["City"].isin(cities)]
new_city
# Out:
#             DATE                          GEO  \
# 12    1979-01-01            Edmonton, Alberta
# 13    1979-01-01             Calgary, Alberta
# 14    1979-01-01  Vancouver, British Columbia
# 27    1979-02-01            Edmonton, Alberta
# 28    1979-02-01             Calgary, Alberta
# ...          ...                          ...
# 41925 2021-10-01             Calgary, Alberta
# 41926 2021-10-01  Vancouver, British Columbia
# 41927 2021-10-01  Vancouver, British Columbia
# 41928 2021-10-01  Vancouver, British Columbia
# 41929 2021-10-01  Vancouver, British Columbia
#
#                                                     TYPE  VALUE       City  \
# 12     Regular unleaded gasoline at full service fill...   18.3   Edmonton
# 13     Regular unleaded gasoline at full service fill...   18.7    Calgary
# 14     Regular unleaded gasoline at full service fill...   21.8  Vancouver
# 27     Regular unleaded gasoline at full service fill...   18.5   Edmonton
# 28     Regular unleaded gasoline at full service fill...   18.9    Calgary
# ...                                                  ...    ...        ...
# 41925       Diesel fuel at self service filling stations  138.3    Calgary
# 41926  Regular unleaded gasoline at self service fill...  162.4  Vancouver
# 41927  Premium unleaded gasoline at self service fill...  184.9  Vancouver
# 41928       Diesel fuel at self service filling stations  161.2  Vancouver
# 41929                             Household heating fuel  148.6  Vancouver
#
#                 Province Month  Year
# 12               Alberta   Jan  1979
# 13               Alberta   Jan  1979
# 14      British Columbia   Jan  1979
# 27               Alberta   Feb  1979
# 28               Alberta   Feb  1979
# ...                  ...   ...   ...
# 41925            Alberta   Oct  2021
# 41926   British Columbia   Oct  2021
# 41927   British Columbia   Oct  2021
# 41928   British Columbia   Oct  2021
# 41929   British Columbia   Oct  2021
#
# [6709 rows x 8 columns]

# %%
dat_copy.City.unique()
# Out:
# array(["St. John's", 'Charlottetown and Summerside', 'Halifax',
#        'Saint John', 'Québec', 'Montréal', 'Ottawa-Gatineau', 'Toronto',
#        'Thunder Bay', 'Winnipeg', 'Regina', 'Saskatoon', 'Edmonton',
#        'Calgary', 'Vancouver', 'Victoria', 'Whitehorse', 'Yellowknife'],
#       dtype=object)

# %%
mulit_filter = dat_copy[(dat_copy["TYPE"]=="Household heating fuel") & (dat_copy["City"]=="Vancouver") & (dat_copy["Year"]>=1990 ) & (dat_copy["Year"]<=2021)]
mulit_filter
# Out:
#             DATE                          GEO                    TYPE  VALUE  \
# 2192  1990-01-01  Vancouver, British Columbia  Household heating fuel   32.4
# 2304  1990-02-01  Vancouver, British Columbia  Household heating fuel   33.7
# 2416  1990-03-01  Vancouver, British Columbia  Household heating fuel   34.0
# 2528  1990-04-01  Vancouver, British Columbia  Household heating fuel   34.5
# 2640  1990-05-01  Vancouver, British Columbia  Household heating fuel   34.5
# ...          ...                          ...                     ...    ...
# 41653 2021-06-01  Vancouver, British Columbia  Household heating fuel  133.1
# 41722 2021-07-01  Vancouver, British Columbia  Household heating fuel  135.2
# 41791 2021-08-01  Vancouver, British Columbia  Household heating fuel  136.5
# 41860 2021-09-01  Vancouver, British Columbia  Household heating fuel  140.9
# 41929 2021-10-01  Vancouver, British Columbia  Household heating fuel  148.6
#
#             City           Province Month  Year
# 2192   Vancouver   British Columbia   Jan  1990
# 2304   Vancouver   British Columbia   Feb  1990
# 2416   Vancouver   British Columbia   Mar  1990
# 2528   Vancouver   British Columbia   Apr  1990
# 2640   Vancouver   British Columbia   May  1990
# ...          ...                ...   ...   ...
# 41653  Vancouver   British Columbia   Jun  2021
# 41722  Vancouver   British Columbia   Jul  2021
# 41791  Vancouver   British Columbia   Aug  2021
# 41860  Vancouver   British Columbia   Sep  2021
# 41929  Vancouver   British Columbia   Oct  2021
#
# [382 rows x 8 columns]

# %%
data_group_by_GEO = dat_copy.groupby("GEO")
data_group_by_GEO.ngroup()
# Out:
# 0        10
# 1         1
# 2         3
# 3         8
# 4         6
#          ..
# 41937    15
# 41938    17
# 41939    17
# 41940    17
# 41941    17
# Length: 41942, dtype: int64

# %%
group_year = dat_copy.groupby(['Year'])['VALUE'].describe()
group_year
# Out:
#        count        mean        std   min      25%     50%      75%    max
# Year
# 1979   180.0   23.604444   2.339336  18.3   22.700   23.60   25.400   29.6
# 1980   192.0   28.068750   2.860649  21.3   26.500   27.95   29.925   35.4
# 1981   192.0   38.002604   4.380770  27.4   34.775   38.60   41.000   50.6
# 1982   192.0   44.701563   5.690697  33.1   40.325   44.45   49.050   57.6
# 1983   192.0   47.904688   6.183649  26.4   42.625   48.60   52.125   58.8
# 1984   192.0   50.442708   5.280484  37.9   45.300   50.50   54.675   61.0
# 1985   192.0   53.899479   5.538750  42.3   48.850   54.00   58.200   65.3
# 1986   192.0   48.405208   7.337508  31.2   42.725   47.90   53.500   66.7
# 1987   192.0   49.758333   4.964738  34.7   47.175   50.05   52.775   58.0
# 1988   192.0   49.217187   4.933597  37.2   45.750   49.95   52.900   58.1
# 1989   192.0   51.700000   4.662539  35.2   48.475   52.40   54.900   59.3
# 1990  1344.0   55.048735  10.251247  29.2   49.700   57.00   61.725   79.2
# 1991  1372.0   56.527041   9.667079  34.4   50.175   57.40   63.200   83.5
# 1992  1404.0   54.633832   9.080337  34.9   49.100   56.20   61.000   72.4
# 1993  1428.0   54.334734   8.599033  34.7   50.000   55.40   59.900   72.4
# 1994  1428.0   54.247899   9.113414  32.8   49.300   55.00   60.425   75.9
# 1995  1428.0   56.177451  10.097989  32.3   50.000   57.00   63.700   78.4
# 1996  1416.0   58.134110  10.132678  33.3   52.275   58.90   65.225   80.9
# 1997  1416.0   59.182062   9.310168  33.7   53.700   59.80   64.500   80.6
# 1998  1416.0   56.247246   9.851861  29.9   50.600   56.70   63.300   80.4
# 1999  1416.0   58.743362  11.253431  28.6   51.500   59.20   67.000   85.1
# 2000  1416.0   72.207839  11.072512  42.3   64.500   73.30   80.300   98.2
# 2001  1416.0   72.403107  10.954948  42.7   64.700   72.40   80.300  101.6
# 2002  1416.0   70.312147  11.979794  37.3   62.000   71.20   79.000  100.4
# 2003  1416.0   75.541667  11.735071  45.9   67.175   76.30   84.200  107.0
# 2004  1416.0   82.960452  12.503012  50.7   73.700   83.90   92.200  111.4
# 2005  1416.0   96.328743  12.375078  63.9   87.800   96.35  104.000  137.5
# 2006  1416.0  101.209393  12.637885  68.7   91.900  100.50  110.550  133.5
# 2007  1416.0  105.258263  11.682542  74.0   96.700  105.25  113.700  141.6
# 2008  1416.0  123.340678  18.151417  69.5  112.350  124.30  136.825  163.0
# 2009  1416.0   96.969068  12.327857  65.5   88.400   97.20  106.000  130.9
# 2010  1416.0  106.369845  10.712664  78.9   99.075  106.65  113.300  135.5
# 2011  1416.0  126.790607  11.141010  91.7  119.100  127.60  134.525  157.3
# 2012  1416.0  130.380085  11.503854  94.4  121.900  131.15  138.900  161.1
# 2013   880.0  129.677273  11.953011  90.2  121.675  130.80  138.225  162.3
# 2014   828.0  133.169203  12.340048  84.5  126.000  134.50  141.900  167.4
# 2015   828.0  110.366908  13.398402  72.4  100.600  109.90  119.225  151.3
# 2016   828.0  101.790821  14.429888  63.1   91.700  100.55  111.350  146.6
# 2017   828.0  112.852657  14.164847  72.9  102.675  112.70  121.025  160.8
# 2018   828.0  129.408575  14.413331  93.7  120.775  128.45  137.800  179.6
# 2019   828.0  125.776329  15.316430  88.6  115.750  125.50  135.400  189.3
# 2020   828.0  107.617150  17.961406  55.7   95.575  105.90  120.100  168.0
# 2021   690.0  133.990580  18.247423  81.3  121.700  133.05  146.650  191.6
