# %%
import numpy as np
import pandas as pd

# Pivot Tables
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)

# %%
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    287     41   John  January      Q1
# 1  2023-01-02       B   West    197     11   Mary  January      Q1
# 2  2023-01-03       C  North    810     68    Bob  January      Q1
# 3  2023-01-04       D  South    783     27  Alice  January      Q1
# 4  2023-01-05       A   East    415     94   John  January      Q1
# 5  2023-01-06       B   West    734     10   Mary  January      Q1
# 6  2023-01-07       C  North    843     58    Bob  January      Q1
# 7  2023-01-08       D  South    825     22  Alice  January      Q1
# 8  2023-01-09       A   East    307     13   John  January      Q1
# 9  2023-01-10       B   West    278     90   Mary  January      Q1
# 10 2023-01-11       C  North    104     89    Bob  January      Q1
# 11 2023-01-12       D  South    792     26  Alice  January      Q1
# 12 2023-01-13       A   East    810     25   John  January      Q1
# 13 2023-01-14       B   West    863     93   Mary  January      Q1
# 14 2023-01-15       C  North    528     28    Bob  January      Q1
# 15 2023-01-16       D  South    264     51  Alice  January      Q1
# 16 2023-01-17       A   East    697     26   John  January      Q1
# 17 2023-01-18       B   West    492     81   Mary  January      Q1
# 18 2023-01-19       C  North    608     57    Bob  January      Q1
# 19 2023-01-20       D  South    819     72  Alice  January      Q1

# %%
pv1 = pd.pivot_table(df, values="Sales", index="Region", columns="Product", aggfunc="median")
pv1
# Out:
# Product      A      B      C      D
# Region
# East     415.0    NaN    NaN    NaN
# North      NaN    NaN  608.0    NaN
# South      NaN    NaN    NaN  792.0
# West       NaN  492.0    NaN    NaN

# %%
pv2 = pd.pivot_table(df, values=["Sales", "Units"], index="Region", columns="Product", aggfunc="median")
pv2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     415.0    NaN    NaN    NaN  26.0   NaN   NaN   NaN
# North      NaN    NaN  608.0    NaN   NaN   NaN  58.0   NaN
# South      NaN    NaN    NaN  792.0   NaN   NaN   NaN  27.0
# West       NaN  492.0    NaN    NaN   NaN  81.0   NaN   NaN

# %% [markdown]
# ## Cross Tabs

# %%
ct = pd.crosstab(df["Region"], df["Product"])
ct
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
